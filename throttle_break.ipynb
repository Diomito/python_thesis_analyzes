# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tkinter as tk
from tkinter import filedialog
import numpy as np
import statistics

# %%
df2 = pd.read_csv('new_data_log2.csv', sep=',')
df3 = pd.read_csv('new_data_log03.csv', sep=',')
df4 = pd.read_csv('new_data_log04.csv', sep=',')
df5 = pd.read_csv('new_data_log05.csv', sep=',')
df6 = pd.read_csv('new_data_log06.csv', sep=',')
df8 = pd.read_csv('new_data_log08.csv', sep=',')
df9 = pd.read_csv('new_data_log09.csv', sep=',')
df10 = pd.read_csv('new_data_log10.csv', sep=',')
df11 = pd.read_csv('new_data_log11.csv', sep=',')
df12 = pd.read_csv('new_data_log12.csv', sep=',')
df13 = pd.read_csv('new_data_log13.csv', sep=',')
df14 = pd.read_csv('new_data_log14.csv', sep=',')
df16 = pd.read_csv('new_data_log16.csv', sep=',')
df17 = pd.read_csv('new_data_log17.csv', sep=',')

# %%
plt.figure(figsize=(12,8))

for df in [df2, df3, df4, df5, df6, df8, df9, df10, df11, df12, df13, df14, df16, df17]:
    plt.plot(df['Seconds'], df['Brake'] * 100)

plt.xlabel('Time')
plt.ylabel('Brake')
plt.title('Time vs Brake')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,8))

mean_brake = np.zeros_like(df2['Brake'])
dfs = [df2, df3, df4, df5, df6, df8, df9, df10, df11, df12, df13, df14, df16, df17]

for df in dfs:
    mean_brake += df['Brake']

mean_brake /= len(dfs)

plt.plot(df2['Seconds'], mean_brake*100)

plt.xlabel('Time', fontsize=14)
plt.ylabel('Brake %', fontsize=14)
plt.title('Brake (Scenario C)', fontsize=20)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))

for df in [df2, df3, df4, df5, df6, df8, df9, df10, df11, df12, df13, df14, df16, df17]:
    plt.plot(df['Seconds'], df['Throttle'] * 100)

plt.xlabel('Time')
plt.ylabel('Throttle')
plt.title('Time vs Throttle')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,8))

mean_throttle = np.zeros_like(df2['Throttle'])
dfs = [df2, df3, df4, df5, df6, df8, df9, df10, df11, df12, df13, df14, df16, df17]

for df in dfs:
    mean_throttle += df['Throttle']

mean_throttle /= len(dfs)

plt.plot(df2['Seconds'], mean_throttle * 100)

plt.xlabel('Time')
plt.ylabel('Throttle %')
plt.title('Throttle (Scenario C)')
plt.grid(True)
plt.tight_layout()
plt.show()
